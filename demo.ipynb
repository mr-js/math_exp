# %%
import random

numbers = []
for i in range(10000):
    numbers.append(random.randint(0, 36))

# %%
for i in range(100):
    print(f'{i} : {numbers[i]}')
# Out:
# 0 : 16
# 1 : 17
# 2 : 35
# 3 : 19
# 4 : 1
# 5 : 13
# 6 : 26
# 7 : 7
# 8 : 36
# 9 : 3
# 10 : 0
# 11 : 11
# 12 : 21
# 13 : 19
# 14 : 24
# 15 : 10
# 16 : 12
# 17 : 8
# 18 : 33
# 19 : 8
# 20 : 4
# 21 : 36
# 22 : 6
# 23 : 12
# 24 : 35
# 25 : 22
# 26 : 2
# 27 : 33
# 28 : 5
# 29 : 16
# 30 : 13
# 31 : 36
# 32 : 14
# 33 : 29
# 34 : 2
# 35 : 6
# 36 : 26
# 37 : 11
# 38 : 25
# 39 : 11
# 40 : 22
# 41 : 27
# 42 : 6
# 43 : 15
# 44 : 29
# 45 : 23
# 46 : 32
# 47 : 34
# 48 : 15
# 49 : 9
# 50 : 1
# 51 : 1
# 52 : 4
# 53 : 17
# 54 : 8
# 55 : 25
# 56 : 6
# 57 : 6
# 58 : 7
# 59 : 5
# 60 : 28
# 61 : 14
# 62 : 16
# 63 : 0
# 64 : 4
# 65 : 33
# 66 : 9
# 67 : 28
# 68 : 21
# 69 : 20
# 70 : 28
# 71 : 10
# 72 : 5
# 73 : 6
# 74 : 33
# 75 : 19
# 76 : 15
# 77 : 28
# 78 : 11
# 79 : 11
# 80 : 19
# 81 : 18
# 82 : 3
# 83 : 11
# 84 : 8
# 85 : 34
# 86 : 15
# 87 : 3
# 88 : 0
# 89 : 14
# 90 : 17
# 91 : 14
# 92 : 11
# 93 : 27
# 94 : 3
# 95 : 28
# 96 : 15
# 97 : 25
# 98 : 35
# 99 : 18
